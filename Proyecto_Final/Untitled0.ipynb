# %% [markdown]
# #Corrección automática de examenes

# %% [markdown]
# En el presente trabajo se utilizará un dataset que consta de ocho grupos de "ensayos" con una extensión promedio de 150 a 550 palabras. El objetivo es aprender a utilizar texto como variable de entrada, el cual requiere una etapa de preprocesado diferente al utilizar otro tipo de variables (numéricas, categoricas, etc...). Esto se llevará a cabo implementando diferentes modelos de clasificación que permitan asignar una calificacion a cada "ensayo".

# %% [markdown]
# ##Dataset

# %% [markdown]
# Para cargar el dataaset, monto drive y localizo la carpeta que contiene el archivo ".json" del API de Kaggle que permite descargar el dataset. Luego lo copio a mi carpeta personal

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/gdrive/MyDrive/UNS/Aprendizaje_de_maquina/Proyecto_Final'

# %%
# !kaggle competitions download -c asap-aes
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.10 / client 1.5.4)
# valid_sample_submission_2_column.csv: Skipping, found more recently modified local copy (use --force to force download)
# test_set.tsv.zip: Skipping, found more recently modified local copy (use --force to force download)
# valid_sample_submission_5_column.csv: Skipping, found more recently modified local copy (use --force to force download)
# training_set_rel3.xlsx.zip: Skipping, found more recently modified local copy (use --force to force download)
# valid_set.tsv.zip: Skipping, found more recently modified local copy (use --force to force download)
# Training_Materials.zip: Skipping, found more recently modified local copy (use --force to force download)
# valid_sample_submission_1_column.csv: Skipping, found more recently modified local copy (use --force to force download)
# training_set_rel3.xls.zip: Skipping, found more recently modified local copy (use --force to force download)
# valid_sample_submission_1_column_no_header.csv: Skipping, found more recently modified local copy (use --force to force download)
# valid_set.xlsx.zip: Skipping, found more recently modified local copy (use --force to force download)
# valid_set.xls.zip: Skipping, found more recently modified local copy (use --force to force download)
# training_set_rel3.tsv.zip: Skipping, found more recently modified local copy (use --force to force download)
# Essay_Set_Descriptions.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
#path that contains folder you want to copy
# %cd /content
# %cp -av /content /gdrive/MyDrive/UNS/Aprendizaje_de_maquina/Proyecto_Final

# %% [markdown]
# ##prepocess

# %% [markdown]
# ##modelos y otras yerbas

# %% [markdown]
# ##resultados y conclusiones
